# %%
# !pip install PublicDataReader
# Out:
# ...
#   Using cached PublicDataReader-1.0.18-py3-none-any.whl (3.2 MB)
# ...
#   Using cached xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# ...

# %%
from PublicDataReader import TransactionPrice

service_key = "lQDUgIbOTXNT3QKizGRnUGwDtr6TqDtF/472wWleLgc8Tpys27nOrzu0xAye/Jq12taAfMbeAhoJGc6P3GDoxQ=="
api = TransactionPrice(service_key)

# %%
df = api.get_data(   
       property_type="아파트",
    trade_type="매매",
    sigungu_code="11650",
    year_month="202212")
df
# Out:
#      지역코드        도로명  법정동       지번          아파트  건축년도   층     전용면적     년   월  \
# 0   11650       서초대로  방배동    421-1   세양아르비채101동  2006   5  147.573  2022  12
# 1   11650      방배중앙로  방배동     3282     방배중앙센트레빌  2021   2   59.933  2022  12
# 2   11650  남부순환로289길  방배동    483-1         서희융창  2003   5  101.830  2022  12
# 3   11650      동광로1길  방배동    754-1       롯데캐슬헤론  2006  14  124.270  2022  12
# 4   11650  남부순환로289길  방배동    483-1         서희융창  2003   7   70.020  2022  12
# 5   11650     잠원로14길  잠원동       50      롯데캐슬갤럭시  2002   6  133.410  2022  12
# 6   11650    신반포로33길  잠원동      157           동아  2002   1   59.800  2022  12
# 7   11650      잠원로3길  잠원동    71-17        중앙하이츠  1998   4   59.930  2022  12
# 8   11650        잠원로  잠원동       70         신반포4  1979  13  100.110  2022  12
# 9   11650       신반포로  반포동      968    에이아이디차관주택  1974   1   72.510  2022  12
# 10  11650       신반포로  반포동    20-43         반포자이  2009  14  165.446  2022  12
# ...

# %%
df.to_excel("result_202212.xlsx",encoding='utf-8-sig') # 파일로 저장하기
