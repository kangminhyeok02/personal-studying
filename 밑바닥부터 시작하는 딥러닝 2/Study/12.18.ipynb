# %% [markdown]
# ### seq2seq 개선
#
# ##### 학습 속도를 개선하자 !
#
# 1) 입렉 데이터 반전 (Reverse)
#
# ![image.png](attachment:image.png)
#
# - '나' 'I' 사이의 거리가 더 가까워져 기울기가 더 잘 전해져서 학습 효율이 좋아짐
#
#
#
# 2) 엿보기 (Peeky)
#
# ![image-2.png](attachment:image-2.png)
#
# - Encoder에서 나오는 은닉벡터를 처음 LSTM 뿐만 아니라 다른 LSTM에도 확장해서 사용하는 것
# - LSTM과 Affine 계층에서 두개의 입력값을 concat 하여 해결!
