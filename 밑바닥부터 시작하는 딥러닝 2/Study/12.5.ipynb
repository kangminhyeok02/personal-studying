# %% [markdown]
# 기존 통계 기반 기법은 단어의 동시발생 행렬을 만들고 그 행렬에 SVD를 적용하여 밀집벡터(단어의 분산표현)을 얻었다
#
# BUT , 대규모 말뭉치를 다룰 경우 문제 발생함   -> 추론기반 기법

# %% [markdown]
# 추론 기반 기법 : Word2Vec
# - 미니배치 학습

# %%
#CBOW 모델 추론과정(주변 맥락 정보로 Target 예측)
import sys
sys.path.append('..')
import numpy as np 
from common.layers import MatMul

#sample data
c0=np.array([[1,0,0,0,0,0,0]])
c1=np.array([[0,0,1,0,0,0,0]])
#가중치 초기화 
W_in = np.random.rand(7,3)
W_out = np.random.rand(3,7)
#layer 생성
in_layer0=MatMul(W_in)
in_layer1=MatMul(W_in)
out_layer=MatMul(W_out)
#순전파

h0=in_layer0.forward(c0)
h1=in_layer1.forward(c1)
h=0.5*(h0+h1)
s = out_layer.forward(h)

print(s)
# Out:
# [[1.69650411 0.56800966 1.13832288 1.00766358 0.52345123 0.88216886
#   1.31093246]]

# %% [markdown]
# CBOW 모델 구현

# %%
#data 준비 과정 
from common.util import preprocess,create_contexts_target,convert_one_hot

text ='You say goodbye and I say hello.'
corpus,word_to_id,id_to_word = preprocess(text)

context,target = create_contexts_target(corpus,window_size=1)

vocab_size=len(word_to_id)
target = convert_one_hot(target,vocab_size)
context = convert_one_hot(context,vocab_size)

# %%
#simpleCBOW 구현
from common.layers import MatMul,SoftmaxWithLoss

class SimpleCBOW:
    def __init__(self, vocab_size, hidden_size):
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(H, V).astype('f')

        # 계층 생성
        self.in_layer0 = MatMul(W_in)
        self.in_layer1 = MatMul(W_in)
        self.out_layer = MatMul(W_out)
        self.loss_layer = SoftmaxWithLoss()

        # 모든 가중치와 기울기를 리스트에 모은다.
        layers = [self.in_layer0, self.in_layer1, self.out_layer]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h0 = self.in_layer0.forward(contexts[:, 0])
        h1 = self.in_layer1.forward(contexts[:, 1])
        h = (h0 + h1) * 0.5
        score = self.out_layer.forward(h)
        loss = self.loss_layer.forward(score, target)
        return loss

    def backward(self, dout=1):
        ds = self.loss_layer.backward(dout)
        da = self.out_layer.backward(ds)
        da *= 0.5
        self.in_layer1.backward(da)
        self.in_layer0.backward(da)
        return None

# %%
#실행
# coding: utf-8
import sys
sys.path.append('..')  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
from common.trainer import Trainer
from common.optimizer import Adam
from common.util import preprocess, create_contexts_target, convert_one_hot


window_size = 1
hidden_size = 5
batch_size = 3
max_epoch = 1000

text = 'You say goodbye and I say hello.'
corpus, word_to_id, id_to_word = preprocess(text)

vocab_size = len(word_to_id)
contexts, target = create_contexts_target(corpus, window_size)
target = convert_one_hot(target, vocab_size)
contexts = convert_one_hot(contexts, vocab_size)

model = SimpleCBOW(vocab_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()
# Out:
# | 에폭 1 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 2 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 3 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 4 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 5 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 6 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 7 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 8 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 9 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 10 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 11 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 12 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 13 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 14 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 15 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 16 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 17 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 18 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 19 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 20 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 21 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 22 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 23 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 24 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 25 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 26 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 27 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 28 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 29 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 30 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 31 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 32 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 33 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 34 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 35 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 36 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 37 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 38 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 39 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 40 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 41 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 42 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 43 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 44 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 45 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 46 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 47 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 48 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 49 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 50 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 51 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 52 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 53 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 54 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 55 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 56 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 57 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 58 |  반복 1 / 2 | 시간 0[s] | 손실 1.88
# | 에폭 59 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 60 |  반복 1 / 2 | 시간 0[s] | 손실 1.88
# | 에폭 61 |  반복 1 / 2 | 시간 0[s] | 손실 1.88
# | 에폭 62 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 63 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 64 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 65 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 66 |  반복 1 / 2 | 시간 0[s] | 손실 1.86
# | 에폭 67 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 68 |  반복 1 / 2 | 시간 0[s] | 손실 1.86
# | 에폭 69 |  반복 1 / 2 | 시간 0[s] | 손실 1.86
# | 에폭 70 |  반복 1 / 2 | 시간 0[s] | 손실 1.85
# | 에폭 71 |  반복 1 / 2 | 시간 0[s] | 손실 1.85
# | 에폭 72 |  반복 1 / 2 | 시간 0[s] | 손실 1.85
# | 에폭 73 |  반복 1 / 2 | 시간 0[s] | 손실 1.85
# | 에폭 74 |  반복 1 / 2 | 시간 0[s] | 손실 1.84
# | 에폭 75 |  반복 1 / 2 | 시간 0[s] | 손실 1.84
# | 에폭 76 |  반복 1 / 2 | 시간 0[s] | 손실 1.83
# | 에폭 77 |  반복 1 / 2 | 시간 0[s] | 손실 1.83
# | 에폭 78 |  반복 1 / 2 | 시간 0[s] | 손실 1.83
# | 에폭 79 |  반복 1 / 2 | 시간 0[s] | 손실 1.83
# | 에폭 80 |  반복 1 / 2 | 시간 0[s] | 손실 1.82
# | 에폭 81 |  반복 1 / 2 | 시간 0[s] | 손실 1.83
# | 에폭 82 |  반복 1 / 2 | 시간 0[s] | 손실 1.81
# | 에폭 83 |  반복 1 / 2 | 시간 0[s] | 손실 1.81
# | 에폭 84 |  반복 1 / 2 | 시간 0[s] | 손실 1.81
# | 에폭 85 |  반복 1 / 2 | 시간 0[s] | 손실 1.80
# | 에폭 86 |  반복 1 / 2 | 시간 0[s] | 손실 1.80
# | 에폭 87 |  반복 1 / 2 | 시간 0[s] | 손실 1.80
# | 에폭 88 |  반복 1 / 2 | 시간 0[s] | 손실 1.79
# | 에폭 89 |  반복 1 / 2 | 시간 0[s] | 손실 1.79
# | 에폭 90 |  반복 1 / 2 | 시간 0[s] | 손실 1.79
# | 에폭 91 |  반복 1 / 2 | 시간 0[s] | 손실 1.78
# | 에폭 92 |  반복 1 / 2 | 시간 0[s] | 손실 1.78
# | 에폭 93 |  반복 1 / 2 | 시간 0[s] | 손실 1.76
# | 에폭 94 |  반복 1 / 2 | 시간 0[s] | 손실 1.78
# | 에폭 95 |  반복 1 / 2 | 시간 0[s] | 손실 1.77
# | 에폭 96 |  반복 1 / 2 | 시간 0[s] | 손실 1.76
# | 에폭 97 |  반복 1 / 2 | 시간 0[s] | 손실 1.76
# | 에폭 98 |  반복 1 / 2 | 시간 0[s] | 손실 1.75
# | 에폭 99 |  반복 1 / 2 | 시간 0[s] | 손실 1.75
# | 에폭 100 |  반복 1 / 2 | 시간 0[s] | 손실 1.75
# | 에폭 101 |  반복 1 / 2 | 시간 0[s] | 손실 1.75
# | 에폭 102 |  반복 1 / 2 | 시간 0[s] | 손실 1.74
# | 에폭 103 |  반복 1 / 2 | 시간 0[s] | 손실 1.73
# | 에폭 104 |  반복 1 / 2 | 시간 0[s] | 손실 1.73
# | 에폭 105 |  반복 1 / 2 | 시간 0[s] | 손실 1.73
# | 에폭 106 |  반복 1 / 2 | 시간 0[s] | 손실 1.71
# | 에폭 107 |  반복 1 / 2 | 시간 0[s] | 손실 1.72
# | 에폭 108 |  반복 1 / 2 | 시간 0[s] | 손실 1.72
# | 에폭 109 |  반복 1 / 2 | 시간 0[s] | 손실 1.70
# | 에폭 110 |  반복 1 / 2 | 시간 0[s] | 손실 1.70
# | 에폭 111 |  반복 1 / 2 | 시간 0[s] | 손실 1.71
# | 에폭 112 |  반복 1 / 2 | 시간 0[s] | 손실 1.69
# | 에폭 113 |  반복 1 / 2 | 시간 0[s] | 손실 1.70
# | 에폭 114 |  반복 1 / 2 | 시간 0[s] | 손실 1.67
# | 에폭 115 |  반복 1 / 2 | 시간 0[s] | 손실 1.69
# | 에폭 116 |  반복 1 / 2 | 시간 0[s] | 손실 1.67
# | 에폭 117 |  반복 1 / 2 | 시간 0[s] | 손실 1.68
# | 에폭 118 |  반복 1 / 2 | 시간 0[s] | 손실 1.66
# | 에폭 119 |  반복 1 / 2 | 시간 0[s] | 손실 1.67
# | 에폭 120 |  반복 1 / 2 | 시간 0[s] | 손실 1.65
# | 에폭 121 |  반복 1 / 2 | 시간 0[s] | 손실 1.66
# | 에폭 122 |  반복 1 / 2 | 시간 0[s] | 손실 1.64
# | 에폭 123 |  반복 1 / 2 | 시간 0[s] | 손실 1.64
# | 에폭 124 |  반복 1 / 2 | 시간 0[s] | 손실 1.65
# | 에폭 125 |  반복 1 / 2 | 시간 0[s] | 손실 1.65
# | 에폭 126 |  반복 1 / 2 | 시간 0[s] | 손실 1.61
# | 에폭 127 |  반복 1 / 2 | 시간 0[s] | 손실 1.64
# | 에폭 128 |  반복 1 / 2 | 시간 0[s] | 손실 1.62
# | 에폭 129 |  반복 1 / 2 | 시간 0[s] | 손실 1.62
# | 에폭 130 |  반복 1 / 2 | 시간 0[s] | 손실 1.62
# | 에폭 131 |  반복 1 / 2 | 시간 0[s] | 손실 1.59
# | 에폭 132 |  반복 1 / 2 | 시간 0[s] | 손실 1.62
# | 에폭 133 |  반복 1 / 2 | 시간 0[s] | 손실 1.60
# | 에폭 134 |  반복 1 / 2 | 시간 0[s] | 손실 1.59
# | 에폭 135 |  반복 1 / 2 | 시간 0[s] | 손실 1.58
# | 에폭 136 |  반복 1 / 2 | 시간 0[s] | 손실 1.57
# | 에폭 137 |  반복 1 / 2 | 시간 0[s] | 손실 1.59
# | 에폭 138 |  반복 1 / 2 | 시간 0[s] | 손실 1.58
# | 에폭 139 |  반복 1 / 2 | 시간 0[s] | 손실 1.57
# | 에폭 140 |  반복 1 / 2 | 시간 0[s] | 손실 1.56
# | 에폭 141 |  반복 1 / 2 | 시간 0[s] | 손실 1.57
# | 에폭 142 |  반복 1 / 2 | 시간 0[s] | 손실 1.53
# | 에폭 143 |  반복 1 / 2 | 시간 0[s] | 손실 1.55
# | 에폭 144 |  반복 1 / 2 | 시간 0[s] | 손실 1.57
# | 에폭 145 |  반복 1 / 2 | 시간 0[s] | 손실 1.54
# | 에폭 146 |  반복 1 / 2 | 시간 0[s] | 손실 1.52
# | 에폭 147 |  반복 1 / 2 | 시간 0[s] | 손실 1.54
# | 에폭 148 |  반복 1 / 2 | 시간 0[s] | 손실 1.52
# | 에폭 149 |  반복 1 / 2 | 시간 0[s] | 손실 1.53
# | 에폭 150 |  반복 1 / 2 | 시간 0[s] | 손실 1.52
# | 에폭 151 |  반복 1 / 2 | 시간 0[s] | 손실 1.49
# | 에폭 152 |  반복 1 / 2 | 시간 0[s] | 손실 1.50
# | 에폭 153 |  반복 1 / 2 | 시간 0[s] | 손실 1.51
# | 에폭 154 |  반복 1 / 2 | 시간 0[s] | 손실 1.49
# | 에폭 155 |  반복 1 / 2 | 시간 0[s] | 손실 1.49
# | 에폭 156 |  반복 1 / 2 | 시간 0[s] | 손실 1.50
# | 에폭 157 |  반복 1 / 2 | 시간 0[s] | 손실 1.47
# | 에폭 158 |  반복 1 / 2 | 시간 0[s] | 손실 1.47
# | 에폭 159 |  반복 1 / 2 | 시간 0[s] | 손실 1.49
# | 에폭 160 |  반복 1 / 2 | 시간 0[s] | 손실 1.42
# | 에폭 161 |  반복 1 / 2 | 시간 0[s] | 손실 1.48
# | 에폭 162 |  반복 1 / 2 | 시간 0[s] | 손실 1.45
# | 에폭 163 |  반복 1 / 2 | 시간 0[s] | 손실 1.48
# | 에폭 164 |  반복 1 / 2 | 시간 0[s] | 손실 1.42
# | 에폭 165 |  반복 1 / 2 | 시간 0[s] | 손실 1.44
# | 에폭 166 |  반복 1 / 2 | 시간 0[s] | 손실 1.44
# | 에폭 167 |  반복 1 / 2 | 시간 0[s] | 손실 1.43
# | 에폭 168 |  반복 1 / 2 | 시간 0[s] | 손실 1.43
# | 에폭 169 |  반복 1 / 2 | 시간 0[s] | 손실 1.42
# | 에폭 170 |  반복 1 / 2 | 시간 0[s] | 손실 1.42
# | 에폭 171 |  반복 1 / 2 | 시간 0[s] | 손실 1.41
# | 에폭 172 |  반복 1 / 2 | 시간 0[s] | 손실 1.40
# | 에폭 173 |  반복 1 / 2 | 시간 0[s] | 손실 1.40
# | 에폭 174 |  반복 1 / 2 | 시간 0[s] | 손실 1.40
# | 에폭 175 |  반복 1 / 2 | 시간 0[s] | 손실 1.42
# | 에폭 176 |  반복 1 / 2 | 시간 0[s] | 손실 1.35
# | 에폭 177 |  반복 1 / 2 | 시간 0[s] | 손실 1.41
# | 에폭 178 |  반복 1 / 2 | 시간 0[s] | 손실 1.36
# | 에폭 179 |  반복 1 / 2 | 시간 0[s] | 손실 1.37
# | 에폭 180 |  반복 1 / 2 | 시간 0[s] | 손실 1.40
# | 에폭 181 |  반복 1 / 2 | 시간 0[s] | 손실 1.37
# | 에폭 182 |  반복 1 / 2 | 시간 0[s] | 손실 1.30
# | 에폭 183 |  반복 1 / 2 | 시간 0[s] | 손실 1.37
# | 에폭 184 |  반복 1 / 2 | 시간 0[s] | 손실 1.33
# | 에폭 185 |  반복 1 / 2 | 시간 0[s] | 손실 1.35
# | 에폭 186 |  반복 1 / 2 | 시간 0[s] | 손실 1.34
# | 에폭 187 |  반복 1 / 2 | 시간 0[s] | 손실 1.36
# | 에폭 188 |  반복 1 / 2 | 시간 0[s] | 손실 1.33
# | 에폭 189 |  반복 1 / 2 | 시간 0[s] | 손실 1.33
# | 에폭 190 |  반복 1 / 2 | 시간 0[s] | 손실 1.32
# | 에폭 191 |  반복 1 / 2 | 시간 0[s] | 손실 1.32
# | 에폭 192 |  반복 1 / 2 | 시간 0[s] | 손실 1.35
# | 에폭 193 |  반복 1 / 2 | 시간 0[s] | 손실 1.27
# | 에폭 194 |  반복 1 / 2 | 시간 0[s] | 손실 1.31
# | 에폭 195 |  반복 1 / 2 | 시간 0[s] | 손실 1.26
# | 에폭 196 |  반복 1 / 2 | 시간 0[s] | 손실 1.32
# | 에폭 197 |  반복 1 / 2 | 시간 0[s] | 손실 1.34
# | 에폭 198 |  반복 1 / 2 | 시간 0[s] | 손실 1.28
# | 에폭 199 |  반복 1 / 2 | 시간 0[s] | 손실 1.28
# | 에폭 200 |  반복 1 / 2 | 시간 0[s] | 손실 1.24
# | 에폭 201 |  반복 1 / 2 | 시간 0[s] | 손실 1.28
# | 에폭 202 |  반복 1 / 2 | 시간 0[s] | 손실 1.22
# | 에폭 203 |  반복 1 / 2 | 시간 0[s] | 손실 1.31
# | 에폭 204 |  반복 1 / 2 | 시간 0[s] | 손실 1.22
# | 에폭 205 |  반복 1 / 2 | 시간 0[s] | 손실 1.30
# | 에폭 206 |  반복 1 / 2 | 시간 0[s] | 손실 1.28
# | 에폭 207 |  반복 1 / 2 | 시간 0[s] | 손실 1.25
# | 에폭 208 |  반복 1 / 2 | 시간 0[s] | 손실 1.24
# | 에폭 209 |  반복 1 / 2 | 시간 0[s] | 손실 1.21
# | 에폭 210 |  반복 1 / 2 | 시간 0[s] | 손실 1.23
# | 에폭 211 |  반복 1 / 2 | 시간 0[s] | 손실 1.24
# | 에폭 212 |  반복 1 / 2 | 시간 0[s] | 손실 1.26
# | 에폭 213 |  반복 1 / 2 | 시간 0[s] | 손실 1.14
# | 에폭 214 |  반복 1 / 2 | 시간 0[s] | 손실 1.26
# | 에폭 215 |  반복 1 / 2 | 시간 0[s] | 손실 1.22
# | 에폭 216 |  반복 1 / 2 | 시간 0[s] | 손실 1.21
# | 에폭 217 |  반복 1 / 2 | 시간 0[s] | 손실 1.25
# | 에폭 218 |  반복 1 / 2 | 시간 0[s] | 손실 1.11
# | 에폭 219 |  반복 1 / 2 | 시간 0[s] | 손실 1.29
# | 에폭 220 |  반복 1 / 2 | 시간 0[s] | 손실 1.15
# | 에폭 221 |  반복 1 / 2 | 시간 0[s] | 손실 1.24
# | 에폭 222 |  반복 1 / 2 | 시간 0[s] | 손실 1.18
# | 에폭 223 |  반복 1 / 2 | 시간 0[s] | 손실 1.14
# | 에폭 224 |  반복 1 / 2 | 시간 0[s] | 손실 1.17
# | 에폭 225 |  반복 1 / 2 | 시간 0[s] | 손실 1.18
# | 에폭 226 |  반복 1 / 2 | 시간 0[s] | 손실 1.17
# | 에폭 227 |  반복 1 / 2 | 시간 0[s] | 손실 1.21
# | 에폭 228 |  반복 1 / 2 | 시간 0[s] | 손실 1.07
# | 에폭 229 |  반복 1 / 2 | 시간 0[s] | 손실 1.16
# | 에폭 230 |  반복 1 / 2 | 시간 0[s] | 손실 1.26
# | 에폭 231 |  반복 1 / 2 | 시간 0[s] | 손실 1.10
# | 에폭 232 |  반복 1 / 2 | 시간 0[s] | 손실 1.15
# | 에폭 233 |  반복 1 / 2 | 시간 0[s] | 손실 1.20
# | 에폭 234 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 235 |  반복 1 / 2 | 시간 0[s] | 손실 1.15
# | 에폭 236 |  반복 1 / 2 | 시간 0[s] | 손실 1.07
# | 에폭 237 |  반복 1 / 2 | 시간 0[s] | 손실 1.14
# | 에폭 238 |  반복 1 / 2 | 시간 0[s] | 손실 1.18
# | 에폭 239 |  반복 1 / 2 | 시간 0[s] | 손실 1.13
# | 에폭 240 |  반복 1 / 2 | 시간 0[s] | 손실 1.11
# | 에폭 241 |  반복 1 / 2 | 시간 0[s] | 손실 1.18
# | 에폭 242 |  반복 1 / 2 | 시간 0[s] | 손실 1.05
# | 에폭 243 |  반복 1 / 2 | 시간 0[s] | 손실 1.17
# | 에폭 244 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 245 |  반복 1 / 2 | 시간 0[s] | 손실 1.11
# | 에폭 246 |  반복 1 / 2 | 시간 0[s] | 손실 1.16
# | 에폭 247 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 248 |  반복 1 / 2 | 시간 0[s] | 손실 1.15
# | 에폭 249 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 250 |  반복 1 / 2 | 시간 0[s] | 손실 1.09
# | 에폭 251 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 252 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 253 |  반복 1 / 2 | 시간 0[s] | 손실 1.20
# | 에폭 254 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 255 |  반복 1 / 2 | 시간 0[s] | 손실 1.14
# | 에폭 256 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 257 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 258 |  반복 1 / 2 | 시간 0[s] | 손실 1.13
# | 에폭 259 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 260 |  반복 1 / 2 | 시간 0[s] | 손실 1.12
# | 에폭 261 |  반복 1 / 2 | 시간 0[s] | 손실 1.12
# | 에폭 262 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 263 |  반복 1 / 2 | 시간 0[s] | 손실 1.12
# | 에폭 264 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 265 |  반복 1 / 2 | 시간 0[s] | 손실 0.97
# | 에폭 266 |  반복 1 / 2 | 시간 0[s] | 손실 1.05
# | 에폭 267 |  반복 1 / 2 | 시간 0[s] | 손실 1.03
# | 에폭 268 |  반복 1 / 2 | 시간 0[s] | 손실 0.96
# | 에폭 269 |  반복 1 / 2 | 시간 0[s] | 손실 1.10
# | 에폭 270 |  반복 1 / 2 | 시간 0[s] | 손실 1.03
# | 에폭 271 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 272 |  반복 1 / 2 | 시간 0[s] | 손실 1.09
# | 에폭 273 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 274 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 275 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 276 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 277 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 278 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 279 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 280 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 281 |  반복 1 / 2 | 시간 0[s] | 손실 1.06
# | 에폭 282 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 283 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 284 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 285 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 286 |  반복 1 / 2 | 시간 0[s] | 손실 0.92
# | 에폭 287 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 288 |  반복 1 / 2 | 시간 0[s] | 손실 0.97
# | 에폭 289 |  반복 1 / 2 | 시간 0[s] | 손실 1.05
# | 에폭 290 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 291 |  반복 1 / 2 | 시간 0[s] | 손실 0.97
# | 에폭 292 |  반복 1 / 2 | 시간 0[s] | 손실 0.89
# | 에폭 293 |  반복 1 / 2 | 시간 0[s] | 손실 1.12
# | 에폭 294 |  반복 1 / 2 | 시간 0[s] | 손실 0.97
# | 에폭 295 |  반복 1 / 2 | 시간 0[s] | 손실 0.96
# | 에폭 296 |  반복 1 / 2 | 시간 0[s] | 손실 0.88
# | 에폭 297 |  반복 1 / 2 | 시간 0[s] | 손실 0.96
# | 에폭 298 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 299 |  반복 1 / 2 | 시간 0[s] | 손실 1.03
# | 에폭 300 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 301 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 302 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 303 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 304 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 305 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 306 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 307 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 308 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 309 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 310 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 311 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 312 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 313 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 314 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 315 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 316 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 317 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 318 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 319 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 320 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 321 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 322 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 323 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 324 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 325 |  반복 1 / 2 | 시간 0[s] | 손실 1.06
# | 에폭 326 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 327 |  반복 1 / 2 | 시간 0[s] | 손실 0.97
# | 에폭 328 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 329 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 330 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 331 |  반복 1 / 2 | 시간 0[s] | 손실 0.88
# | 에폭 332 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 333 |  반복 1 / 2 | 시간 0[s] | 손실 0.89
# | 에폭 334 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 335 |  반복 1 / 2 | 시간 0[s] | 손실 0.97
# | 에폭 336 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 337 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 338 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 339 |  반복 1 / 2 | 시간 0[s] | 손실 0.96
# | 에폭 340 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 341 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 342 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 343 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 344 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 345 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 346 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 347 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 348 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 349 |  반복 1 / 2 | 시간 0[s] | 손실 0.85
# | 에폭 350 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 351 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 352 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 353 |  반복 1 / 2 | 시간 0[s] | 손실 0.82
# | 에폭 354 |  반복 1 / 2 | 시간 0[s] | 손실 0.92
# | 에폭 355 |  반복 1 / 2 | 시간 0[s] | 손실 0.85
# | 에폭 356 |  반복 1 / 2 | 시간 0[s] | 손실 0.82
# | 에폭 357 |  반복 1 / 2 | 시간 0[s] | 손실 0.85
# | 에폭 358 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 359 |  반복 1 / 2 | 시간 0[s] | 손실 0.92
# | 에폭 360 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 361 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 362 |  반복 1 / 2 | 시간 0[s] | 손실 0.82
# | 에폭 363 |  반복 1 / 2 | 시간 0[s] | 손실 0.92
# | 에폭 364 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 365 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 366 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 367 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 368 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 369 |  반복 1 / 2 | 시간 0[s] | 손실 0.89
# | 에폭 370 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 371 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 372 |  반복 1 / 2 | 시간 0[s] | 손실 0.89
# | 에폭 373 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 374 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 375 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 376 |  반복 1 / 2 | 시간 0[s] | 손실 0.82
# | 에폭 377 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 378 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 379 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 380 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 381 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 382 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 383 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 384 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 385 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 386 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 387 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 388 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 389 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 390 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 391 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 392 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 393 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 394 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 395 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 396 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 397 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 398 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 399 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 400 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 401 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 402 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 403 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 404 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 405 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 406 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 407 |  반복 1 / 2 | 시간 0[s] | 손실 0.82
# | 에폭 408 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 409 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 410 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 411 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 412 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 413 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 414 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 415 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 416 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 417 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 418 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 419 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 420 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 421 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 422 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 423 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 424 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 425 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 426 |  반복 1 / 2 | 시간 0[s] | 손실 0.89
# | 에폭 427 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 428 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 429 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 430 |  반복 1 / 2 | 시간 0[s] | 손실 0.82
# | 에폭 431 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 432 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 433 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 434 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 435 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 436 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 437 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 438 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 439 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 440 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 441 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 442 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 443 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 444 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 445 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 446 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 447 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 448 |  반복 1 / 2 | 시간 0[s] | 손실 0.82
# | 에폭 449 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 450 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 451 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 452 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 453 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 454 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 455 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 456 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 457 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 458 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 459 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 460 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 461 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 462 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 463 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 464 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 465 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 466 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 467 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 468 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 469 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 470 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 471 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 472 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 473 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 474 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 475 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 476 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 477 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 478 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 479 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 480 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 481 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 482 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 483 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 484 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 485 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 486 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 487 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 488 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 489 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 490 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 491 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 492 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 493 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 494 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 495 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 496 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 497 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 498 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 499 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 500 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 501 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 502 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 503 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 504 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 505 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 506 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 507 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 508 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 509 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 510 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 511 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 512 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 513 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 514 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 515 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 516 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 517 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 518 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 519 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 520 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 521 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 522 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 523 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 524 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 525 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 526 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 527 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 528 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 529 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 530 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 531 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 532 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 533 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 534 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 535 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 536 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 537 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 538 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 539 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 540 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 541 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 542 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 543 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 544 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 545 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 546 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 547 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 548 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 549 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 550 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 551 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 552 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 553 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 554 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 555 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 556 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 557 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 558 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 559 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 560 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 561 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 562 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 563 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 564 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 565 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 566 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 567 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 568 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 569 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 570 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 571 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 572 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 573 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 574 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 575 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 576 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 577 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 578 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 579 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 580 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 581 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 582 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 583 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 584 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 585 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 586 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 587 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 588 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 589 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 590 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 591 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 592 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 593 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 594 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 595 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 596 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 597 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 598 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 599 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 600 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 601 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 602 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 603 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 604 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 605 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 606 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 607 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 608 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 609 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 610 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 611 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 612 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 613 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 614 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 615 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 616 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 617 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 618 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 619 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 620 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 621 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 622 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 623 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 624 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 625 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 626 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 627 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 628 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 629 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 630 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 631 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 632 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 633 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 634 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 635 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 636 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 637 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 638 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 639 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 640 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 641 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 642 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 643 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 644 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 645 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 646 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 647 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 648 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 649 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 650 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 651 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 652 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 653 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 654 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 655 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 656 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 657 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 658 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 659 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 660 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 661 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 662 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 663 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 664 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 665 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 666 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 667 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 668 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 669 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 670 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 671 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 672 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 673 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 674 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 675 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 676 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 677 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 678 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 679 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 680 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 681 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 682 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 683 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 684 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 685 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 686 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 687 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 688 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 689 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 690 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 691 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 692 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 693 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 694 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 695 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 696 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 697 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 698 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 699 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 700 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 701 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 702 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 703 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 704 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 705 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 706 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 707 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 708 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 709 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 710 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 711 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 712 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 713 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 714 |  반복 1 / 2 | 시간 0[s] | 손실 0.31
# | 에폭 715 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 716 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 717 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 718 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 719 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 720 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 721 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 722 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 723 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 724 |  반복 1 / 2 | 시간 0[s] | 손실 0.31
# | 에폭 725 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 726 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 727 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 728 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 729 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 730 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 731 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 732 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 733 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 734 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 735 |  반복 1 / 2 | 시간 0[s] | 손실 0.24
# | 에폭 736 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 737 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 738 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 739 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 740 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 741 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 742 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 743 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 744 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 745 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 746 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 747 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 748 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 749 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 750 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 751 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 752 |  반복 1 / 2 | 시간 0[s] | 손실 0.22
# | 에폭 753 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 754 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 755 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 756 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 757 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 758 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 759 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 760 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 761 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 762 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 763 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 764 |  반복 1 / 2 | 시간 0[s] | 손실 0.29
# | 에폭 765 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 766 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 767 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 768 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 769 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 770 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 771 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 772 |  반복 1 / 2 | 시간 0[s] | 손실 0.28
# | 에폭 773 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 774 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 775 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 776 |  반복 1 / 2 | 시간 0[s] | 손실 0.20
# | 에폭 777 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 778 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 779 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 780 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 781 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 782 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 783 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 784 |  반복 1 / 2 | 시간 0[s] | 손실 0.31
# | 에폭 785 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 786 |  반복 1 / 2 | 시간 0[s] | 손실 0.19
# | 에폭 787 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 788 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 789 |  반복 1 / 2 | 시간 0[s] | 손실 0.27
# | 에폭 790 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 791 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 792 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 793 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 794 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 795 |  반복 1 / 2 | 시간 0[s] | 손실 0.20
# | 에폭 796 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 797 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 798 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 799 |  반복 1 / 2 | 시간 0[s] | 손실 0.21
# | 에폭 800 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 801 |  반복 1 / 2 | 시간 0[s] | 손실 0.28
# | 에폭 802 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 803 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 804 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 805 |  반복 1 / 2 | 시간 0[s] | 손실 0.27
# | 에폭 806 |  반복 1 / 2 | 시간 0[s] | 손실 0.30
# | 에폭 807 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 808 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 809 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 810 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 811 |  반복 1 / 2 | 시간 0[s] | 손실 0.18
# | 에폭 812 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 813 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 814 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 815 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 816 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 817 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 818 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 819 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 820 |  반복 1 / 2 | 시간 0[s] | 손실 0.28
# | 에폭 821 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 822 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 823 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 824 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 825 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 826 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 827 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 828 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 829 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 830 |  반복 1 / 2 | 시간 0[s] | 손실 0.27
# | 에폭 831 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 832 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 833 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 834 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 835 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 836 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 837 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 838 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 839 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 840 |  반복 1 / 2 | 시간 0[s] | 손실 0.27
# | 에폭 841 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 842 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 843 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 844 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 845 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 846 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 847 |  반복 1 / 2 | 시간 0[s] | 손실 0.27
# | 에폭 848 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 849 |  반복 1 / 2 | 시간 0[s] | 손실 0.29
# | 에폭 850 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 851 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 852 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 853 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 854 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 855 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 856 |  반복 1 / 2 | 시간 0[s] | 손실 0.27
# | 에폭 857 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 858 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 859 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 860 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 861 |  반복 1 / 2 | 시간 0[s] | 손실 0.13
# | 에폭 862 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 863 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 864 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 865 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 866 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 867 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 868 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 869 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 870 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 871 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 872 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 873 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 874 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 875 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 876 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 877 |  반복 1 / 2 | 시간 0[s] | 손실 0.16
# | 에폭 878 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 879 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 880 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 881 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 882 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 883 |  반복 1 / 2 | 시간 0[s] | 손실 0.13
# | 에폭 884 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 885 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 886 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 887 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 888 |  반복 1 / 2 | 시간 0[s] | 손실 0.26
# | 에폭 889 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 890 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 891 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 892 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 893 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 894 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 895 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 896 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 897 |  반복 1 / 2 | 시간 0[s] | 손실 0.24
# | 에폭 898 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 899 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 900 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 901 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 902 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 903 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 904 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 905 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 906 |  반복 1 / 2 | 시간 0[s] | 손실 0.24
# | 에폭 907 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 908 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 909 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 910 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 911 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 912 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 913 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 914 |  반복 1 / 2 | 시간 0[s] | 손실 0.24
# | 에폭 915 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 916 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 917 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 918 |  반복 1 / 2 | 시간 0[s] | 손실 0.23
# | 에폭 919 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 920 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 921 |  반복 1 / 2 | 시간 0[s] | 손실 0.24
# | 에폭 922 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 923 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 924 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 925 |  반복 1 / 2 | 시간 0[s] | 손실 0.24
# | 에폭 926 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 927 |  반복 1 / 2 | 시간 0[s] | 손실 0.23
# | 에폭 928 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 929 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 930 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 931 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 932 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 933 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 934 |  반복 1 / 2 | 시간 0[s] | 손실 0.24
# | 에폭 935 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 936 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 937 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 938 |  반복 1 / 2 | 시간 0[s] | 손실 0.23
# | 에폭 939 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 940 |  반복 1 / 2 | 시간 0[s] | 손실 0.12
# | 에폭 941 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 942 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 943 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 944 |  반복 1 / 2 | 시간 0[s] | 손실 0.13
# | 에폭 945 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 946 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 947 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 948 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 949 |  반복 1 / 2 | 시간 0[s] | 손실 0.12
# | 에폭 950 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 951 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 952 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 953 |  반복 1 / 2 | 시간 0[s] | 손실 0.22
# | 에폭 954 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 955 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 956 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 957 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 958 |  반복 1 / 2 | 시간 0[s] | 손실 0.23
# | 에폭 959 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 960 |  반복 1 / 2 | 시간 0[s] | 손실 0.22
# | 에폭 961 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 962 |  반복 1 / 2 | 시간 0[s] | 손실 0.21
# | 에폭 963 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 964 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 965 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 966 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 967 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 968 |  반복 1 / 2 | 시간 0[s] | 손실 0.23
# | 에폭 969 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 970 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 971 |  반복 1 / 2 | 시간 0[s] | 손실 0.22
# | 에폭 972 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 973 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 974 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 975 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 976 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 977 |  반복 1 / 2 | 시간 0[s] | 손실 0.22
# | 에폭 978 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 979 |  반복 1 / 2 | 시간 0[s] | 손실 0.22
# | 에폭 980 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 981 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 982 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 983 |  반복 1 / 2 | 시간 0[s] | 손실 0.21
# | 에폭 984 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 985 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 986 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 987 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 988 |  반복 1 / 2 | 시간 0[s] | 손실 0.31
# | 에폭 989 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 990 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 991 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 992 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 993 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 994 |  반복 1 / 2 | 시간 0[s] | 손실 0.23
# | 에폭 995 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 996 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 997 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 998 |  반복 1 / 2 | 시간 0[s] | 손실 0.23
# | 에폭 999 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 1000 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# C:\Users\rkdal\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rkdal\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48373 (\N{HANGUL SYLLABLE BOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rkdal\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rkdal\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
window_size = 1
hidden_size = 5
batch_size = 3
max_epoch = 1000

text = 'You say goodbye and I say hello.'
corpus, word_to_id, id_to_word = preprocess(text)

vocab_size = len(word_to_id)
contexts, target = create_contexts_target(corpus, window_size)
target = convert_one_hot(target, vocab_size)
contexts = convert_one_hot(contexts, vocab_size)

model = SimpleCBOW(vocab_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

word_vecs = model.word_vecs
for word_id, word in id_to_word.items():
    print(word, word_vecs[word_id])
# Out:
# | 에폭 1 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 2 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 3 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 4 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 5 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 6 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 7 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 8 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 9 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 10 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 11 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 12 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 13 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 14 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 15 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 16 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 17 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 18 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 19 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 20 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 21 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 22 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 23 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 24 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 25 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 26 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 27 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 28 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 29 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 30 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 31 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 32 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 33 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 34 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 35 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 36 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 37 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 38 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 39 |  반복 1 / 2 | 시간 0[s] | 손실 1.93
# | 에폭 40 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 41 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 42 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 43 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 44 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 45 |  반복 1 / 2 | 시간 0[s] | 손실 1.92
# | 에폭 46 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 47 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 48 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 49 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 50 |  반복 1 / 2 | 시간 0[s] | 손실 1.91
# | 에폭 51 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 52 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 53 |  반복 1 / 2 | 시간 0[s] | 손실 1.90
# | 에폭 54 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 55 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 56 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 57 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 58 |  반복 1 / 2 | 시간 0[s] | 손실 1.88
# | 에폭 59 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 60 |  반복 1 / 2 | 시간 0[s] | 손실 1.89
# | 에폭 61 |  반복 1 / 2 | 시간 0[s] | 손실 1.88
# | 에폭 62 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 63 |  반복 1 / 2 | 시간 0[s] | 손실 1.88
# | 에폭 64 |  반복 1 / 2 | 시간 0[s] | 손실 1.86
# | 에폭 65 |  반복 1 / 2 | 시간 0[s] | 손실 1.86
# | 에폭 66 |  반복 1 / 2 | 시간 0[s] | 손실 1.88
# | 에폭 67 |  반복 1 / 2 | 시간 0[s] | 손실 1.86
# | 에폭 68 |  반복 1 / 2 | 시간 0[s] | 손실 1.83
# | 에폭 69 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 70 |  반복 1 / 2 | 시간 0[s] | 손실 1.86
# | 에폭 71 |  반복 1 / 2 | 시간 0[s] | 손실 1.83
# | 에폭 72 |  반복 1 / 2 | 시간 0[s] | 손실 1.87
# | 에폭 73 |  반복 1 / 2 | 시간 0[s] | 손실 1.84
# | 에폭 74 |  반복 1 / 2 | 시간 0[s] | 손실 1.84
# | 에폭 75 |  반복 1 / 2 | 시간 0[s] | 손실 1.82
# | 에폭 76 |  반복 1 / 2 | 시간 0[s] | 손실 1.83
# | 에폭 77 |  반복 1 / 2 | 시간 0[s] | 손실 1.84
# | 에폭 78 |  반복 1 / 2 | 시간 0[s] | 손실 1.81
# | 에폭 79 |  반복 1 / 2 | 시간 0[s] | 손실 1.84
# | 에폭 80 |  반복 1 / 2 | 시간 0[s] | 손실 1.82
# | 에폭 81 |  반복 1 / 2 | 시간 0[s] | 손실 1.80
# | 에폭 82 |  반복 1 / 2 | 시간 0[s] | 손실 1.81
# | 에폭 83 |  반복 1 / 2 | 시간 0[s] | 손실 1.81
# | 에폭 84 |  반복 1 / 2 | 시간 0[s] | 손실 1.78
# | 에폭 85 |  반복 1 / 2 | 시간 0[s] | 손실 1.82
# | 에폭 86 |  반복 1 / 2 | 시간 0[s] | 손실 1.77
# | 에폭 87 |  반복 1 / 2 | 시간 0[s] | 손실 1.79
# | 에폭 88 |  반복 1 / 2 | 시간 0[s] | 손실 1.82
# | 에폭 89 |  반복 1 / 2 | 시간 0[s] | 손실 1.76
# | 에폭 90 |  반복 1 / 2 | 시간 0[s] | 손실 1.76
# | 에폭 91 |  반복 1 / 2 | 시간 0[s] | 손실 1.79
# | 에폭 92 |  반복 1 / 2 | 시간 0[s] | 손실 1.79
# | 에폭 93 |  반복 1 / 2 | 시간 0[s] | 손실 1.75
# | 에폭 94 |  반복 1 / 2 | 시간 0[s] | 손실 1.78
# | 에폭 95 |  반복 1 / 2 | 시간 0[s] | 손실 1.74
# | 에폭 96 |  반복 1 / 2 | 시간 0[s] | 손실 1.73
# | 에폭 97 |  반복 1 / 2 | 시간 0[s] | 손실 1.79
# | 에폭 98 |  반복 1 / 2 | 시간 0[s] | 손실 1.73
# | 에폭 99 |  반복 1 / 2 | 시간 0[s] | 손실 1.73
# | 에폭 100 |  반복 1 / 2 | 시간 0[s] | 손실 1.71
# | 에폭 101 |  반복 1 / 2 | 시간 0[s] | 손실 1.78
# | 에폭 102 |  반복 1 / 2 | 시간 0[s] | 손실 1.73
# | 에폭 103 |  반복 1 / 2 | 시간 0[s] | 손실 1.70
# | 에폭 104 |  반복 1 / 2 | 시간 0[s] | 손실 1.71
# | 에폭 105 |  반복 1 / 2 | 시간 0[s] | 손실 1.72
# | 에폭 106 |  반복 1 / 2 | 시간 0[s] | 손실 1.71
# | 에폭 107 |  반복 1 / 2 | 시간 0[s] | 손실 1.71
# | 에폭 108 |  반복 1 / 2 | 시간 0[s] | 손실 1.69
# | 에폭 109 |  반복 1 / 2 | 시간 0[s] | 손실 1.67
# | 에폭 110 |  반복 1 / 2 | 시간 0[s] | 손실 1.71
# | 에폭 111 |  반복 1 / 2 | 시간 0[s] | 손실 1.72
# | 에폭 112 |  반복 1 / 2 | 시간 0[s] | 손실 1.65
# | 에폭 113 |  반복 1 / 2 | 시간 0[s] | 손실 1.68
# | 에폭 114 |  반복 1 / 2 | 시간 0[s] | 손실 1.68
# | 에폭 115 |  반복 1 / 2 | 시간 0[s] | 손실 1.66
# | 에폭 116 |  반복 1 / 2 | 시간 0[s] | 손실 1.67
# | 에폭 117 |  반복 1 / 2 | 시간 0[s] | 손실 1.69
# | 에폭 118 |  반복 1 / 2 | 시간 0[s] | 손실 1.63
# | 에폭 119 |  반복 1 / 2 | 시간 0[s] | 손실 1.64
# | 에폭 120 |  반복 1 / 2 | 시간 0[s] | 손실 1.69
# | 에폭 121 |  반복 1 / 2 | 시간 0[s] | 손실 1.61
# | 에폭 122 |  반복 1 / 2 | 시간 0[s] | 손실 1.60
# | 에폭 123 |  반복 1 / 2 | 시간 0[s] | 손실 1.69
# | 에폭 124 |  반복 1 / 2 | 시간 0[s] | 손실 1.59
# | 에폭 125 |  반복 1 / 2 | 시간 0[s] | 손실 1.59
# | 에폭 126 |  반복 1 / 2 | 시간 0[s] | 손실 1.68
# | 에폭 127 |  반복 1 / 2 | 시간 0[s] | 손실 1.62
# | 에폭 128 |  반복 1 / 2 | 시간 0[s] | 손실 1.56
# | 에폭 129 |  반복 1 / 2 | 시간 0[s] | 손실 1.64
# | 에폭 130 |  반복 1 / 2 | 시간 0[s] | 손실 1.56
# | 에폭 131 |  반복 1 / 2 | 시간 0[s] | 손실 1.61
# | 에폭 132 |  반복 1 / 2 | 시간 0[s] | 손실 1.55
# | 에폭 133 |  반복 1 / 2 | 시간 0[s] | 손실 1.59
# | 에폭 134 |  반복 1 / 2 | 시간 0[s] | 손실 1.54
# | 에폭 135 |  반복 1 / 2 | 시간 0[s] | 손실 1.57
# | 에폭 136 |  반복 1 / 2 | 시간 0[s] | 손실 1.63
# | 에폭 137 |  반복 1 / 2 | 시간 0[s] | 손실 1.53
# | 에폭 138 |  반복 1 / 2 | 시간 0[s] | 손실 1.60
# | 에폭 139 |  반복 1 / 2 | 시간 0[s] | 손실 1.47
# | 에폭 140 |  반복 1 / 2 | 시간 0[s] | 손실 1.58
# | 에폭 141 |  반복 1 / 2 | 시간 0[s] | 손실 1.53
# | 에폭 142 |  반복 1 / 2 | 시간 0[s] | 손실 1.54
# | 에폭 143 |  반복 1 / 2 | 시간 0[s] | 손실 1.53
# | 에폭 144 |  반복 1 / 2 | 시간 0[s] | 손실 1.52
# | 에폭 145 |  반복 1 / 2 | 시간 0[s] | 손실 1.57
# | 에폭 146 |  반복 1 / 2 | 시간 0[s] | 손실 1.48
# | 에폭 147 |  반복 1 / 2 | 시간 0[s] | 손실 1.50
# | 에폭 148 |  반복 1 / 2 | 시간 0[s] | 손실 1.50
# | 에폭 149 |  반복 1 / 2 | 시간 0[s] | 손실 1.47
# | 에폭 150 |  반복 1 / 2 | 시간 0[s] | 손실 1.54
# | 에폭 151 |  반복 1 / 2 | 시간 0[s] | 손실 1.53
# | 에폭 152 |  반복 1 / 2 | 시간 0[s] | 손실 1.43
# | 에폭 153 |  반복 1 / 2 | 시간 0[s] | 손실 1.48
# | 에폭 154 |  반복 1 / 2 | 시간 0[s] | 손실 1.42
# | 에폭 155 |  반복 1 / 2 | 시간 0[s] | 손실 1.52
# | 에폭 156 |  반복 1 / 2 | 시간 0[s] | 손실 1.53
# | 에폭 157 |  반복 1 / 2 | 시간 0[s] | 손실 1.41
# | 에폭 158 |  반복 1 / 2 | 시간 0[s] | 손실 1.40
# | 에폭 159 |  반복 1 / 2 | 시간 0[s] | 손실 1.45
# | 에폭 160 |  반복 1 / 2 | 시간 0[s] | 손실 1.49
# | 에폭 161 |  반복 1 / 2 | 시간 0[s] | 손실 1.44
# | 에폭 162 |  반복 1 / 2 | 시간 0[s] | 손실 1.44
# | 에폭 163 |  반복 1 / 2 | 시간 0[s] | 손실 1.38
# | 에폭 164 |  반복 1 / 2 | 시간 0[s] | 손실 1.53
# | 에폭 165 |  반복 1 / 2 | 시간 0[s] | 손실 1.35
# | 에폭 166 |  반복 1 / 2 | 시간 0[s] | 손실 1.43
# | 에폭 167 |  반복 1 / 2 | 시간 0[s] | 손실 1.41
# | 에폭 168 |  반복 1 / 2 | 시간 0[s] | 손실 1.44
# | 에폭 169 |  반복 1 / 2 | 시간 0[s] | 손실 1.34
# | 에폭 170 |  반복 1 / 2 | 시간 0[s] | 손실 1.41
# | 에폭 171 |  반복 1 / 2 | 시간 0[s] | 손실 1.39
# | 에폭 172 |  반복 1 / 2 | 시간 0[s] | 손실 1.38
# | 에폭 173 |  반복 1 / 2 | 시간 0[s] | 손실 1.37
# | 에폭 174 |  반복 1 / 2 | 시간 0[s] | 손실 1.37
# | 에폭 175 |  반복 1 / 2 | 시간 0[s] | 손실 1.37
# | 에폭 176 |  반복 1 / 2 | 시간 0[s] | 손실 1.43
# | 에폭 177 |  반복 1 / 2 | 시간 0[s] | 손실 1.29
# | 에폭 178 |  반복 1 / 2 | 시간 0[s] | 손실 1.36
# | 에폭 179 |  반복 1 / 2 | 시간 0[s] | 손실 1.30
# | 에폭 180 |  반복 1 / 2 | 시간 0[s] | 손실 1.40
# | 에폭 181 |  반복 1 / 2 | 시간 0[s] | 손실 1.34
# | 에폭 182 |  반복 1 / 2 | 시간 0[s] | 손실 1.33
# | 에폭 183 |  반복 1 / 2 | 시간 0[s] | 손실 1.34
# | 에폭 184 |  반복 1 / 2 | 시간 0[s] | 손실 1.33
# | 에폭 185 |  반복 1 / 2 | 시간 0[s] | 손실 1.38
# | 에폭 186 |  반복 1 / 2 | 시간 0[s] | 손실 1.26
# | 에폭 187 |  반복 1 / 2 | 시간 0[s] | 손실 1.31
# | 에폭 188 |  반복 1 / 2 | 시간 0[s] | 손실 1.31
# | 에폭 189 |  반복 1 / 2 | 시간 0[s] | 손실 1.30
# | 에폭 190 |  반복 1 / 2 | 시간 0[s] | 손실 1.30
# | 에폭 191 |  반복 1 / 2 | 시간 0[s] | 손실 1.29
# | 에폭 192 |  반복 1 / 2 | 시간 0[s] | 손실 1.24
# | 에폭 193 |  반복 1 / 2 | 시간 0[s] | 손실 1.35
# | 에폭 194 |  반복 1 / 2 | 시간 0[s] | 손실 1.28
# | 에폭 195 |  반복 1 / 2 | 시간 0[s] | 손실 1.28
# | 에폭 196 |  반복 1 / 2 | 시간 0[s] | 손실 1.33
# | 에폭 197 |  반복 1 / 2 | 시간 0[s] | 손실 1.14
# | 에폭 198 |  반복 1 / 2 | 시간 0[s] | 손실 1.26
# | 에폭 199 |  반복 1 / 2 | 시간 0[s] | 손실 1.40
# | 에폭 200 |  반복 1 / 2 | 시간 0[s] | 손실 1.25
# | 에폭 201 |  반복 1 / 2 | 시간 0[s] | 손실 1.26
# | 에폭 202 |  반복 1 / 2 | 시간 0[s] | 손실 1.17
# | 에폭 203 |  반복 1 / 2 | 시간 0[s] | 손실 1.17
# | 에폭 204 |  반복 1 / 2 | 시간 0[s] | 손실 1.31
# | 에폭 205 |  반복 1 / 2 | 시간 0[s] | 손실 1.24
# | 에폭 206 |  반복 1 / 2 | 시간 0[s] | 손실 1.22
# | 에폭 207 |  반복 1 / 2 | 시간 0[s] | 손실 1.23
# | 에폭 208 |  반복 1 / 2 | 시간 0[s] | 손실 1.22
# | 에폭 209 |  반복 1 / 2 | 시간 0[s] | 손실 1.15
# | 에폭 210 |  반복 1 / 2 | 시간 0[s] | 손실 1.28
# | 에폭 211 |  반복 1 / 2 | 시간 0[s] | 손실 1.22
# | 에폭 212 |  반복 1 / 2 | 시간 0[s] | 손실 1.21
# | 에폭 213 |  반복 1 / 2 | 시간 0[s] | 손실 1.27
# | 에폭 214 |  반복 1 / 2 | 시간 0[s] | 손실 1.05
# | 에폭 215 |  반복 1 / 2 | 시간 0[s] | 손실 1.34
# | 에폭 216 |  반복 1 / 2 | 시간 0[s] | 손실 1.11
# | 에폭 217 |  반복 1 / 2 | 시간 0[s] | 손실 1.18
# | 에폭 218 |  반복 1 / 2 | 시간 0[s] | 손실 1.19
# | 에폭 219 |  반복 1 / 2 | 시간 0[s] | 손실 1.11
# | 에폭 220 |  반복 1 / 2 | 시간 0[s] | 손실 1.17
# | 에폭 221 |  반복 1 / 2 | 시간 0[s] | 손실 1.17
# | 에폭 222 |  반복 1 / 2 | 시간 0[s] | 손실 1.32
# | 에폭 223 |  반복 1 / 2 | 시간 0[s] | 손실 1.16
# | 에폭 224 |  반복 1 / 2 | 시간 0[s] | 손실 1.07
# | 에폭 225 |  반복 1 / 2 | 시간 0[s] | 손실 1.16
# | 에폭 226 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 227 |  반복 1 / 2 | 시간 0[s] | 손실 1.22
# | 에폭 228 |  반복 1 / 2 | 시간 0[s] | 손실 1.07
# | 에폭 229 |  반복 1 / 2 | 시간 0[s] | 손실 1.23
# | 에폭 230 |  반복 1 / 2 | 시간 0[s] | 손실 1.14
# | 에폭 231 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 232 |  반복 1 / 2 | 시간 0[s] | 손실 1.15
# | 에폭 233 |  반복 1 / 2 | 시간 0[s] | 손실 1.20
# | 에폭 234 |  반복 1 / 2 | 시간 0[s] | 손실 1.20
# | 에폭 235 |  반복 1 / 2 | 시간 0[s] | 손실 1.03
# | 에폭 236 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 237 |  반복 1 / 2 | 시간 0[s] | 손실 1.11
# | 에폭 238 |  반복 1 / 2 | 시간 0[s] | 손실 1.27
# | 에폭 239 |  반복 1 / 2 | 시간 0[s] | 손실 1.11
# | 에폭 240 |  반복 1 / 2 | 시간 0[s] | 손실 1.10
# | 에폭 241 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 242 |  반복 1 / 2 | 시간 0[s] | 손실 1.10
# | 에폭 243 |  반복 1 / 2 | 시간 0[s] | 손실 1.24
# | 에폭 244 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 245 |  반복 1 / 2 | 시간 0[s] | 손실 1.09
# | 에폭 246 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 247 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 248 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 249 |  반복 1 / 2 | 시간 0[s] | 손실 1.09
# | 에폭 250 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 251 |  반복 1 / 2 | 시간 0[s] | 손실 1.07
# | 에폭 252 |  반복 1 / 2 | 시간 0[s] | 손실 1.15
# | 에폭 253 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 254 |  반복 1 / 2 | 시간 0[s] | 손실 1.06
# | 에폭 255 |  반복 1 / 2 | 시간 0[s] | 손실 1.03
# | 에폭 256 |  반복 1 / 2 | 시간 0[s] | 손실 1.06
# | 에폭 257 |  반복 1 / 2 | 시간 0[s] | 손실 1.07
# | 에폭 258 |  반복 1 / 2 | 시간 0[s] | 손실 1.10
# | 에폭 259 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 260 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 261 |  반복 1 / 2 | 시간 0[s] | 손실 1.15
# | 에폭 262 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 263 |  반복 1 / 2 | 시간 0[s] | 손실 0.96
# | 에폭 264 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 265 |  반복 1 / 2 | 시간 0[s] | 손실 1.09
# | 에폭 266 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 267 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 268 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 269 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 270 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 271 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 272 |  반복 1 / 2 | 시간 0[s] | 손실 1.08
# | 에폭 273 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 274 |  반복 1 / 2 | 시간 0[s] | 손실 0.92
# | 에폭 275 |  반복 1 / 2 | 시간 0[s] | 손실 1.17
# | 에폭 276 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 277 |  반복 1 / 2 | 시간 0[s] | 손실 0.85
# | 에폭 278 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 279 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 280 |  반복 1 / 2 | 시간 0[s] | 손실 0.92
# | 에폭 281 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 282 |  반복 1 / 2 | 시간 0[s] | 손실 1.03
# | 에폭 283 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 284 |  반복 1 / 2 | 시간 0[s] | 손실 1.04
# | 에폭 285 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 286 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 287 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 288 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 289 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 290 |  반복 1 / 2 | 시간 0[s] | 손실 0.85
# | 에폭 291 |  반복 1 / 2 | 시간 0[s] | 손실 0.96
# | 에폭 292 |  반복 1 / 2 | 시간 0[s] | 손실 1.05
# | 에폭 293 |  반복 1 / 2 | 시간 0[s] | 손실 1.03
# | 에폭 294 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 295 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 296 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 297 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 298 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 299 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 300 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 301 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 302 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 303 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 304 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 305 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 306 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 307 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 308 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 309 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 310 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 311 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 312 |  반복 1 / 2 | 시간 0[s] | 손실 1.00
# | 에폭 313 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 314 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 315 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 316 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 317 |  반복 1 / 2 | 시간 0[s] | 손실 0.85
# | 에폭 318 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 319 |  반복 1 / 2 | 시간 0[s] | 손실 0.89
# | 에폭 320 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 321 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 322 |  반복 1 / 2 | 시간 0[s] | 손실 1.01
# | 에폭 323 |  반복 1 / 2 | 시간 0[s] | 손실 0.89
# | 에폭 324 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 325 |  반복 1 / 2 | 시간 0[s] | 손실 0.96
# | 에폭 326 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 327 |  반복 1 / 2 | 시간 0[s] | 손실 0.92
# | 에폭 328 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 329 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 330 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 331 |  반복 1 / 2 | 시간 0[s] | 손실 0.99
# | 에폭 332 |  반복 1 / 2 | 시간 0[s] | 손실 0.92
# | 에폭 333 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 334 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 335 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 336 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 337 |  반복 1 / 2 | 시간 0[s] | 손실 1.02
# | 에폭 338 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 339 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 340 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 341 |  반복 1 / 2 | 시간 0[s] | 손실 0.85
# | 에폭 342 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 343 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 344 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 345 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 346 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 347 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 348 |  반복 1 / 2 | 시간 0[s] | 손실 0.88
# | 에폭 349 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 350 |  반복 1 / 2 | 시간 0[s] | 손실 0.93
# | 에폭 351 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 352 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 353 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 354 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 355 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 356 |  반복 1 / 2 | 시간 0[s] | 손실 0.91
# | 에폭 357 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 358 |  반복 1 / 2 | 시간 0[s] | 손실 0.95
# | 에폭 359 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 360 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 361 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 362 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 363 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 364 |  반복 1 / 2 | 시간 0[s] | 손실 0.97
# | 에폭 365 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 366 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 367 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 368 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 369 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 370 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 371 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 372 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 373 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 374 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 375 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 376 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 377 |  반복 1 / 2 | 시간 0[s] | 손실 0.98
# | 에폭 378 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 379 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 380 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 381 |  반복 1 / 2 | 시간 0[s] | 손실 0.94
# | 에폭 382 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 383 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 384 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 385 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 386 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 387 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 388 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 389 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 390 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 391 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 392 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 393 |  반복 1 / 2 | 시간 0[s] | 손실 0.85
# | 에폭 394 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 395 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 396 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 397 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 398 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 399 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 400 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 401 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 402 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 403 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 404 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 405 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 406 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 407 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 408 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 409 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 410 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 411 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 412 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 413 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 414 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 415 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 416 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 417 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 418 |  반복 1 / 2 | 시간 0[s] | 손실 0.82
# | 에폭 419 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 420 |  반복 1 / 2 | 시간 0[s] | 손실 0.88
# | 에폭 421 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 422 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 423 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 424 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 425 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 426 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 427 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 428 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 429 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 430 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 431 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 432 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 433 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 434 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 435 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 436 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 437 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 438 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 439 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 440 |  반복 1 / 2 | 시간 0[s] | 손실 0.86
# | 에폭 441 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 442 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 443 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 444 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 445 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 446 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 447 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 448 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 449 |  반복 1 / 2 | 시간 0[s] | 손실 0.84
# | 에폭 450 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 451 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 452 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 453 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 454 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 455 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 456 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 457 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 458 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 459 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 460 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 461 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 462 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 463 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 464 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 465 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 466 |  반복 1 / 2 | 시간 0[s] | 손실 0.83
# | 에폭 467 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 468 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 469 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 470 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 471 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 472 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 473 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 474 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 475 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 476 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 477 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 478 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 479 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 480 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 481 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 482 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 483 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 484 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 485 |  반복 1 / 2 | 시간 0[s] | 손실 0.90
# | 에폭 486 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 487 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 488 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 489 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 490 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 491 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 492 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 493 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 494 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 495 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 496 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 497 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 498 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 499 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 500 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 501 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 502 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 503 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 504 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 505 |  반복 1 / 2 | 시간 0[s] | 손실 0.89
# | 에폭 506 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 507 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 508 |  반복 1 / 2 | 시간 0[s] | 손실 0.76
# | 에폭 509 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 510 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 511 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 512 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 513 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 514 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 515 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 516 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 517 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 518 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 519 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 520 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 521 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 522 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 523 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 524 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 525 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 526 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 527 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 528 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 529 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 530 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 531 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 532 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 533 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 534 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 535 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 536 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 537 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 538 |  반복 1 / 2 | 시간 0[s] | 손실 0.87
# | 에폭 539 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 540 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 541 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 542 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 543 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 544 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 545 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 546 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 547 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 548 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 549 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 550 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 551 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 552 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 553 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 554 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 555 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 556 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 557 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 558 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 559 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 560 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 561 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 562 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 563 |  반복 1 / 2 | 시간 0[s] | 손실 0.79
# | 에폭 564 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 565 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 566 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 567 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 568 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 569 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 570 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 571 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 572 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 573 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 574 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 575 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 576 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 577 |  반복 1 / 2 | 시간 0[s] | 손실 0.78
# | 에폭 578 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 579 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 580 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 581 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 582 |  반복 1 / 2 | 시간 0[s] | 손실 0.75
# | 에폭 583 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 584 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 585 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 586 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 587 |  반복 1 / 2 | 시간 0[s] | 손실 0.74
# | 에폭 588 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 589 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 590 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 591 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 592 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 593 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 594 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 595 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 596 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 597 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 598 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 599 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 600 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 601 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 602 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 603 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 604 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 605 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 606 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 607 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 608 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 609 |  반복 1 / 2 | 시간 0[s] | 손실 0.80
# | 에폭 610 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 611 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 612 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 613 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 614 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 615 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 616 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 617 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 618 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 619 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 620 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 621 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 622 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 623 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 624 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 625 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 626 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 627 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 628 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 629 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 630 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 631 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 632 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 633 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 634 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 635 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 636 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 637 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 638 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 639 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 640 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 641 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 642 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 643 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 644 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 645 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 646 |  반복 1 / 2 | 시간 0[s] | 손실 0.81
# | 에폭 647 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 648 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 649 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 650 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 651 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 652 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 653 |  반복 1 / 2 | 시간 0[s] | 손실 0.71
# | 에폭 654 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 655 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 656 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 657 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 658 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 659 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 660 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 661 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 662 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 663 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 664 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 665 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 666 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 667 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 668 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 669 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 670 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 671 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 672 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 673 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 674 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 675 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 676 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 677 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 678 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 679 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 680 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 681 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 682 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 683 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 684 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 685 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 686 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 687 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 688 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 689 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 690 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 691 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 692 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 693 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 694 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 695 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 696 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 697 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 698 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 699 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 700 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 701 |  반복 1 / 2 | 시간 0[s] | 손실 0.72
# | 에폭 702 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 703 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 704 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 705 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 706 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 707 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 708 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 709 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 710 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 711 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 712 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 713 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 714 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 715 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 716 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 717 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 718 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 719 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 720 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 721 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 722 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 723 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 724 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 725 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 726 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 727 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 728 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 729 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 730 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 731 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 732 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 733 |  반복 1 / 2 | 시간 0[s] | 손실 0.73
# | 에폭 734 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 735 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 736 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 737 |  반복 1 / 2 | 시간 0[s] | 손실 0.77
# | 에폭 738 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 739 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 740 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 741 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 742 |  반복 1 / 2 | 시간 0[s] | 손실 0.65
# | 에폭 743 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 744 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 745 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 746 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 747 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 748 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 749 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 750 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 751 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 752 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 753 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 754 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 755 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 756 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 757 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 758 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 759 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 760 |  반복 1 / 2 | 시간 0[s] | 손실 0.68
# | 에폭 761 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 762 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 763 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 764 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 765 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 766 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 767 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 768 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 769 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 770 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 771 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 772 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 773 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 774 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 775 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 776 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 777 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 778 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 779 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 780 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 781 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 782 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 783 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 784 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 785 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 786 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 787 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 788 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 789 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 790 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 791 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 792 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 793 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 794 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 795 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 796 |  반복 1 / 2 | 시간 0[s] | 손실 0.67
# | 에폭 797 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 798 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 799 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 800 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 801 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 802 |  반복 1 / 2 | 시간 0[s] | 손실 0.66
# | 에폭 803 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 804 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 805 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 806 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 807 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 808 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 809 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 810 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 811 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 812 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 813 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 814 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 815 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 816 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 817 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 818 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 819 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 820 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 821 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 822 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 823 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 824 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 825 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 826 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 827 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 828 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 829 |  반복 1 / 2 | 시간 0[s] | 손실 0.69
# | 에폭 830 |  반복 1 / 2 | 시간 0[s] | 손실 0.30
# | 에폭 831 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 832 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 833 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 834 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 835 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 836 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 837 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 838 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 839 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 840 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 841 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 842 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 843 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 844 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 845 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 846 |  반복 1 / 2 | 시간 0[s] | 손실 0.70
# | 에폭 847 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 848 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 849 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 850 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 851 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 852 |  반복 1 / 2 | 시간 0[s] | 손실 0.62
# | 에폭 853 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 854 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 855 |  반복 1 / 2 | 시간 0[s] | 손실 0.29
# | 에폭 856 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 857 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 858 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 859 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 860 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 861 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 862 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 863 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 864 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 865 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 866 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 867 |  반복 1 / 2 | 시간 0[s] | 손실 0.60
# | 에폭 868 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 869 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 870 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 871 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 872 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 873 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 874 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 875 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 876 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 877 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 878 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 879 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 880 |  반복 1 / 2 | 시간 0[s] | 손실 0.29
# | 에폭 881 |  반복 1 / 2 | 시간 0[s] | 손실 0.56
# | 에폭 882 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 883 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 884 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 885 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 886 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 887 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 888 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 889 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 890 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 891 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 892 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 893 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 894 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 895 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 896 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 897 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 898 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 899 |  반복 1 / 2 | 시간 0[s] | 손실 0.28
# | 에폭 900 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 901 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 902 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 903 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 904 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 905 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 906 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 907 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 908 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 909 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 910 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 911 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 912 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 913 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 914 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 915 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 916 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 917 |  반복 1 / 2 | 시간 0[s] | 손실 0.50
# | 에폭 918 |  반복 1 / 2 | 시간 0[s] | 손실 0.35
# | 에폭 919 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 920 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 921 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 922 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 923 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 924 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 925 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 926 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 927 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 928 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 929 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 930 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 931 |  반복 1 / 2 | 시간 0[s] | 손실 0.38
# | 에폭 932 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 933 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 934 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 935 |  반복 1 / 2 | 시간 0[s] | 손실 0.34
# | 에폭 936 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 937 |  반복 1 / 2 | 시간 0[s] | 손실 0.53
# | 에폭 938 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 939 |  반복 1 / 2 | 시간 0[s] | 손실 0.18
# | 에폭 940 |  반복 1 / 2 | 시간 0[s] | 손실 0.64
# | 에폭 941 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 942 |  반복 1 / 2 | 시간 0[s] | 손실 0.57
# | 에폭 943 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 944 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 945 |  반복 1 / 2 | 시간 0[s] | 손실 0.46
# | 에폭 946 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 947 |  반복 1 / 2 | 시간 0[s] | 손실 0.55
# | 에폭 948 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 949 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 950 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 951 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 952 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 953 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 954 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 955 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 956 |  반복 1 / 2 | 시간 0[s] | 손실 0.52
# | 에폭 957 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 958 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 959 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 960 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 961 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# | 에폭 962 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 963 |  반복 1 / 2 | 시간 0[s] | 손실 0.59
# | 에폭 964 |  반복 1 / 2 | 시간 0[s] | 손실 0.37
# | 에폭 965 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 966 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 967 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 968 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 969 |  반복 1 / 2 | 시간 0[s] | 손실 0.47
# | 에폭 970 |  반복 1 / 2 | 시간 0[s] | 손실 0.44
# | 에폭 971 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 972 |  반복 1 / 2 | 시간 0[s] | 손실 0.63
# | 에폭 973 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 974 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 975 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 976 |  반복 1 / 2 | 시간 0[s] | 손실 0.61
# | 에폭 977 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 978 |  반복 1 / 2 | 시간 0[s] | 손실 0.25
# | 에폭 979 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 980 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 981 |  반복 1 / 2 | 시간 0[s] | 손실 0.32
# | 에폭 982 |  반복 1 / 2 | 시간 0[s] | 손실 0.41
# | 에폭 983 |  반복 1 / 2 | 시간 0[s] | 손실 0.48
# | 에폭 984 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 985 |  반복 1 / 2 | 시간 0[s] | 손실 0.58
# | 에폭 986 |  반복 1 / 2 | 시간 0[s] | 손실 0.36
# | 에폭 987 |  반복 1 / 2 | 시간 0[s] | 손실 0.49
# | 에폭 988 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 989 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 990 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 991 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 992 |  반복 1 / 2 | 시간 0[s] | 손실 0.40
# | 에폭 993 |  반복 1 / 2 | 시간 0[s] | 손실 0.33
# | 에폭 994 |  반복 1 / 2 | 시간 0[s] | 손실 0.43
# | 에폭 995 |  반복 1 / 2 | 시간 0[s] | 손실 0.39
# | 에폭 996 |  반복 1 / 2 | 시간 0[s] | 손실 0.45
# | 에폭 997 |  반복 1 / 2 | 시간 0[s] | 손실 0.54
# | 에폭 998 |  반복 1 / 2 | 시간 0[s] | 손실 0.31
# | 에폭 999 |  반복 1 / 2 | 시간 0[s] | 손실 0.51
# | 에폭 1000 |  반복 1 / 2 | 시간 0[s] | 손실 0.42
# you [-0.8797757  0.956054   1.6451365 -0.893782   1.1699522]
# say [ 1.225153  -0.2980345  1.19054    1.2474484 -0.0946538]
# goodbye [-1.1081147   0.9858964  -0.12552378 -1.054665    0.6790316 ]
# and [ 1.051068   -1.5628848   0.77359056  1.0625403   1.6053557 ]
# i [-1.1167356   1.0129776  -0.15081377 -1.0691912   0.6777572 ]
# hello [-0.87059426  0.96187276  1.6676592  -0.88083965  1.1866453 ]
# . [ 1.043391   1.4300623  1.2082323  1.0627067 -1.3653456]
